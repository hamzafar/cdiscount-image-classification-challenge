# %%
import tensorflow as tf

# %%
import pandas as pd
import numpy as np

# %%
import io
import bson                       # this is installed with the pymongo package
import matplotlib.pyplot as plt
from skimage.data import imread   # or, whatever image library you prefer
import multiprocessing as mp      # will come in handy due to the size of the data

# %%
file_dir = 'E://kaggle//Cdiscount//dataset'

# %%
# Simple data processing

data = bson.decode_file_iter(open(file_dir+'//train_example.bson', 'rb'))

prod_to_category = dict()
for c, d in enumerate(data):
    product_id = d['_id']
    category_id = d['category_id'] # This won't be in Test data
    prod_to_category[product_id] = category_id
    for e, pic in enumerate(d['imgs']):
        picture = imread(io.BytesIO(pic['picture']))
        # do something with the picture, etc

prod_to_category = pd.DataFrame.from_dict(prod_to_category, orient='index')
prod_to_category.index.name = '_id'
prod_to_category.rename(columns={0: 'category_id'}, inplace=True)

# %%
prod_to_category.head()
# Out:
#      category_id
# _id
# 0     1000010653
# 1     1000010653
# 2     1000004079
# 3     1000004141
# 4     1000015539

# %%
plt.imshow(picture);
plt.show()

# %%
type(picture)
# Out:
# numpy.ndarray

# %% [markdown]
# Read batch data from MongoDB.
#
# and send to keras datagen or other techinque
#
# 10k images as first step
#
# and train nn
#
# then take reasonable dataset and overfit NN on it
